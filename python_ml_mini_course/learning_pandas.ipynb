# %%
# Version checks
# Python
import sys
print('Python: {}'.format(sys.version))
# scipy
import scipy
print('scipy: {}'.format(scipy.__version__))
# numpy
import numpy
print('numpy: {}'.format(numpy.__version__))
# matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# pandas
import pandas
print('pandas: {}'.format(pandas.__version__))
# scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 2.7.10 (default, Oct 23 2015, 19:19:21)
# [GCC 4.2.1 Compatible Apple LLVM 7.0.0 (clang-700.0.59.5)]
# scipy: 0.13.0b1
# numpy: 1.8.0rc1
# matplotlib: 1.3.1
# pandas: 0.17.1
# sklearn: 0.16.1

# %%
# dataframe practice
import numpy
import pandas
myarray = numpy.array([[1, 2, 3], [4, 5, 6]])
rownames = ['a', 'b']
colnames = ['one', 'two', 'three']
mydataframe = pandas.DataFrame(myarray, index=rownames, columns=colnames)
mydataframe
# Out:
#    one  two  three
# a    1    2      3
# b    4    5      6

# %%
# Florida avg monthly temps
import numpy
import pandas
temparray = numpy.array([
        [58.1, 60.0, 64.9, 69.3, 75.4, 80.0, 81.6, 81.5, 79.4, 72.6, 66.0, 60.0, 70.7],
        [14.5, 15.6, 18.3, 20.7, 24.1, 26.7, 27.6, 27.5, 26.3, 22.6, 18.9, 15.6, 21.5]
    ])
colnames = ['January','February','March','April','May','June','July','August','September','October','November','December','Entire Year']
rownames = ['F', 'C']
mydataframe = pandas.DataFrame(temparray, index=rownames, columns=colnames)
mydataframe
# Out:
#    January  February  March  April   May  June  July  August  September  \
# F     58.1      60.0   64.9   69.3  75.4  80.0  81.6    81.5       79.4
# C     14.5      15.6   18.3   20.7  24.1  26.7  27.6    27.5       26.3
#
#    October  November  December  Entire Year
# F     72.6      66.0      60.0         70.7
# C     22.6      18.9      15.6         21.5

# %%
# Florida avg monthly temps
# %matplotlib inline
import pandas
data = {
        'F': [58.1, 60.0, 64.9, 69.3, 75.4, 80.0, 81.6, 81.5, 79.4, 72.6, 66.0, 60.0, 70.7],
        'C': [14.5, 15.6, 18.3, 20.7, 24.1, 26.7, 27.6, 27.5, 26.3, 22.6, 18.9, 15.6, 21.5]
    }
rownames = ['January','February','March','April','May','June','July','August','September','October','November','December','Entire Year']
colnames = ['F', 'C']
mydataframe = pandas.DataFrame(data, index=rownames, columns=colnames)
mydataframe
# With plot?
import matplotlib.pyplot as plt
plt.plot(data['F'], color='blue', linewidth=2.5, linestyle='-')
plt.plot(data['C'], color='red', linewidth=2.5, linestyle='-')

# %%
# Load CSV using CSV.reader()
# https://docs.python.org/2/library/csv.html
import csv
with open('sample_submission.csv', 'rb') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        print ', '.join(row)
# Out:
# Id, SalePrice
# 1461, 169277.0524984
# 1462, 187758.393988768
# 1463, 183583.683569555
# 1464, 179317.47751083
# 1465, 150730.079976501
# 1466, 177150.989247307
# 1467, 172070.659229164
# 1468, 175110.956519547
# 1469, 162011.698831665
# 1470, 160726.247831419
# 1471, 157933.279456005
# 1472, 145291.245020389
# 1473, 159672.017631819
# 1474, 164167.518301885
# 1475, 150891.638244053
# 1476, 179460.96518734
# 1477, 185034.62891405
# 1478, 182352.192644656
# 1479, 183053.458213802
# 1480, 187823.339254278
# 1481, 186544.114327568
# 1482, 158230.77520516
# 1483, 190552.829321091
# 1484, 147183.67487199
# 1485, 185855.300905493
# 1486, 174350.470676986
# 1487, 201740.620690863
# 1488, 162986.378895754
# 1489, 162330.199085679
# 1490, 165845.938616539
# 1491, 180929.622876974
# 1492, 163481.501519718
# 1493, 187798.076714233
# 1494, 198822.198942566
# 1495, 194868.409899858
# 1496, 152605.298564403
# 1497, 147797.702836811
# 1498, 150521.96899297
# 1499, 146991.630153739
# ...

# %%
# Load CSV using numpy.loadtxt()
# https://docs.scipy.org/doc/numpy-1.10.0/reference/generated/numpy.loadtxt.html
import numpy as np
data = np.loadtxt('sample_submission.csv',
                  skiprows=1,
                  delimiter=',',
                  dtype=[('f0',int),('f1',float)]
                 )
data
# Out:
# array([(1461, 169277.0524984), (1462, 187758.393988768),
#        (1463, 183583.683569555), ..., (2917, 219222.423400059),
#        (2918, 184924.279658997), (2919, 187741.866657478)],
#       dtype=[('f0', '<i8'), ('f1', '<f8')])

# %%
# Load CSV with pandas.read_csv()
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
data = pandas.read_csv('sample_submission.csv', index_col=0)
data
# Out:
#           SalePrice
# Id
# 1461  169277.052498
# 1462  187758.393989
# 1463  183583.683570
# 1464  179317.477511
# 1465  150730.079977
# 1466  177150.989247
# 1467  172070.659229
# 1468  175110.956520
# 1469  162011.698832
# 1470  160726.247831
# 1471  157933.279456
# 1472  145291.245020
# 1473  159672.017632
# 1474  164167.518302
# 1475  150891.638244
# 1476  179460.965187
# 1477  185034.628914
# 1478  182352.192645
# 1479  183053.458214
# 1480  187823.339254
# 1481  186544.114328
# 1482  158230.775205
# 1483  190552.829321
# 1484  147183.674872
# 1485  185855.300905
# 1486  174350.470677
# 1487  201740.620691
# 1488  162986.378896
# 1489  162330.199086
# 1490  165845.938617
# ...             ...
# 2890  160515.850579
# 2891  192167.621096
# 2892  178751.551083
# 2893  198678.894117
# 2894  164553.120272
# 2895  156887.932862
# 2896  164185.777306
# 2897  212992.120631
# 2898  197468.550533
# 2899  180106.843740
# 2900  183972.071057
# 2901  245283.198338
# 2902  170351.963411
# ...

# %%
# Understanding data through descriptive statistics
import pandas as pd
data = pd.read_csv('sample_submission.csv')

print(data.head())
print(data.describe())
print(data.shape)
print(data.columns)
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977
#                 Id      SalePrice
# count  1459.000000    1459.000000
# mean   2190.000000  179183.918243
# std     421.321334   16518.303051
# min    1461.000000  135751.318893
# 25%    1825.500000  168703.011202
# 50%    2190.000000  179208.665698
# 75%    2554.500000  186789.409363
# max    2919.000000  281643.976117
# (1459, 2)
# Index([u'Id', u'SalePrice'], dtype='object')

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL           65     8450   Pave     0      Reg
# 1   2          20       RL           80     9600   Pave     0      Reg
# 2   3          60       RL           68    11250   Pave     0      IR1
# 3   4          70       RL           60     9550   Pave     0      IR1
# 4   5          60       RL           84    14260   Pave     0      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0      0     0           0       0
# 1         Lvl    AllPub    ...            0      0     0           0       0
# 2         Lvl    AllPub    ...            0      0     0           0       0
# 3         Lvl    AllPub    ...            0      0     0           0       0
# 4         Lvl    AllPub    ...            0      0     0           0       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Plotting a histogram
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('sample_submission.csv')
data = pd.DataFrame(data)

bins = 5
plt.hist(data.SalePrice, bins)
# Out:
# (array([ 283.,  972.,  183.,   16.,    5.]),
#  array([ 135751.31889282,  164929.85033761,  194108.3817824 ,
#          223286.9132272 ,  252465.44467199,  281643.97611679]),
#  <a list of 5 Patch objects>)

# %%
df = pd.DataFrame({'col1':np.random.randn(100), 'col2':np.random.randn(100)})
df.hist(layout=(1,2))
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x10d67cad0>,
#         <matplotlib.axes.AxesSubplot object at 0x10b488510>]], dtype=object)

# %%
# Plotting histogram
# %pylab inline 
import pandas as pd
from pandas import Series

np.random.seed(23)
sample = Series(np.random.randn(1,100).ravel())
sample.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 0    0.666988
# 1    0.025813
# 2   -0.777619
# 3    0.948634
# 4    0.701672
# dtype: float64

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(sample, color='y', alpha=0.5)
ax.set_xlabel('Variable Values')
ax.set_ylabel('Counts')

# %%
sample.hist()

# %%
ax.*label*?

# %%
data = pd.read_csv('train.csv')
data = data.fillna(0)
data.head()
# data['YrSold'].hist()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL           65     8450   Pave     0      Reg
# 1   2          20       RL           80     9600   Pave     0      Reg
# 2   3          60       RL           68    11250   Pave     0      IR1
# 3   4          70       RL           60     9550   Pave     0      IR1
# 4   5          60       RL           84    14260   Pave     0      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0      0     0           0       0
# 1         Lvl    AllPub    ...            0      0     0           0       0
# 2         Lvl    AllPub    ...            0      0     0           0       0
# 3         Lvl    AllPub    ...            0      0     0           0       0
# 4         Lvl    AllPub    ...            0      0     0           0       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Scatter plot matrix
# %pylab inline
import matplotlib.pyplot as plt
import pandas
from pandas.tools.plotting import scatter_matrix

url = 'https://goo.gl/vhm1eU'
names = ['preg','plas','pres','skin','test','mass','pedi','age','class']
data = pandas.read_csv(url, names=names)
scatter_matrix(data)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
